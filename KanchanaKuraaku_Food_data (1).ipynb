# %% [markdown]
# # **Indian Food Dataset**

# %% [markdown]
# Known for its aromatic spices, bold flavors, and regional specialties, Indian food is a delightful journey for the taste buds. From the tandoori delights of the North to the coconut-infused dishes of the South, each region offers a unique culinary experience. Indian cuisine not only caters to various palates but also holds a significant place in Indian traditions and celebrations.
#
# name - Name of the dish.
#
# ingredients - Ingredients used in the dish.
#
# diet - Vegetarian/NonVegetarian.
#
# prep_time - Time consumed in preparation of the dish.
#
# cook_time - Time consumed in cooking the dish.
#
# flavor_profile - Sweet/Spicy/other flavor profile.
#
# course - Main Course/ Dessert /Starters.
#
# state - Indian State where the dish originated.
#
# region - Region in which the dish originated.
#
# img_url - URL for the image of dish.

# %%
from google.colab import drive

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import random
from scipy.stats import mstats

# %%
food_data = pd.read_csv('/content/drive/MyDrive/Ifood_new.csv')
pd.options.display.max_rows = 9999

# %%
food_data.shape
# Out:
# (255, 10)

# %%
food_data.columns
# Out:
# Index(['name', 'ingredients', 'diet', 'prep_time', 'cook_time',
#        'flavor_profile', 'course', 'state', 'region', 'img_url'],
#       dtype='object')

# %%
food_data.isna().sum()
# Out:
# name              0
# ingredients       0
# diet              0
# prep_time         0
# cook_time         0
# flavor_profile    0
# course            0
# state             0
# region            1
# img_url           1
# dtype: int64

# %%
food_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            255 non-null    object
#  1   ingredients     255 non-null    object
#  2   diet            255 non-null    object
#  3   prep_time       255 non-null    int64
#  4   cook_time       255 non-null    int64
#  5   flavor_profile  255 non-null    object
#  6   course          255 non-null    object
#  7   state           255 non-null    object
#  8   region          254 non-null    object
#  9   img_url         254 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 20.1+ KB

# %%
food_data.describe()
# Out:
#         prep_time   cook_time
# count  255.000000  255.000000
# mean    31.105882   34.529412
# std     72.554409   48.265650
# min     -1.000000   -1.000000
# 25%     10.000000   20.000000
# 50%     10.000000   30.000000
# 75%     20.000000   40.000000
# max    500.000000  720.000000

# %%
food_data.head(10)
# Out:
#                 name                                        ingredients  \
# 0          Adhirasam   Rice flour, jaggery, ghee, vegetable oil, elachi
# 1          Aloo gobi  Cauliflower, potato, garam masala, turmeric, c...
# 2         Aloo matar  Potato, peas, chillies, ginger, garam masala, ...
# 3         Aloo methi      Potato, fenugreek leaves, chillies, salt, oil
# 4  Aloo shimla mirch  Potato, shimla mirch, garam masala, amchur pow...
# 5         Aloo tikki  Rice flour, potato, bread crumbs, garam masala...
# 6         Alu Pitika        Potatoes, mustard oil, fish, green chillies
# 7               Amti  Kala masala, arhar dal, curry leaves, mustard ...
# 8             Anarsa               Rice flour, jaggery, khus-khus seeds
# 9            Ariselu                          Rice flour, jaggery, ghee
#
#              diet  prep_time  cook_time flavor_profile       course  \
# 0      vegetarian         10         50          sweet      dessert
# 1      vegetarian         10         20          spicy  main course
# 2      vegetarian          5         40          spicy  main course
# 3      vegetarian         10         40         bitter  main course
# 4      vegetarian         10         40          spicy  main course
# 5      vegetarian          5         20          spicy  main course
# 6  non vegetarian          5         20          spicy  main course
# 7      vegetarian         10         45          spicy  main course
# 8      vegetarian         10         50          sweet      dessert
# 9      vegetarian         15         75          sweet      dessert
#
#             state      region  \
# 0     West Bengal        East
# 1          Punjab       North
# 2          Punjab       North
# 3          Punjab       North
# 4          Punjab       North
# 5          Punjab       North
# 6           Assam  North East
# 7     Maharashtra        West
# 8     Maharashtra        West
# 9  Andhra Pradesh       South
#
#                                              img_url
# 0  https://www.crazymasalafood.com/wp-content/ima...
# 1  https://www.vegrecipesofindia.com/wp-content/u...
# 2  https://www.vegrecipesofindia.com/wp-content/u...
# 3  https://www.vegrecipesofindia.com/wp-content/u...
# 4  https://www.vegrecipesofindia.com/wp-content/u...
# 5  https://www.vegrecipesofindia.com/wp-content/u...
# 6  https://www.pepperonpizza.com/wp-content/uploa...
# 7  https://www.vegrecipesofindia.com/wp-content/u...
# 8  https://www.crazymasalafood.com/wp-content/ima...
# 9  https://www.crazymasalafood.com/wp-content/ima...

# %%
data1 = food_data[(food_data['img_url'].isnull()) | (food_data['region'].isnull())]
data1
# Out:
#           name                                        ingredients        diet  \
# 95   Kajjikaya                       Rice flour, jaggery, coconut  vegetarian
# 177   Panjeeri  Whole wheat flour, musk melon seeds, poppy see...  vegetarian
#
#      prep_time  cook_time flavor_profile   course           state region  \
# 95          40         15          sweet  dessert  Andhra Pradesh  South
# 177         10         25          sweet  dessert   Uttar Pradesh    NaN
#
#                                                img_url
# 95                                                 NaN
# 177  https://i0.wp.com/fatimacooks.net/wp-content/u...

# %%
food_data['img_url'] = food_data['img_url'].fillna('https://mirchi.com/os/cdn/content/images/kajjikayalu%20bellam%20athithigruha%20foods_medium_0272585.webp')
food_data['region'] = food_data['region'].fillna('North')

# %%
null_data = food_data[food_data.isnull()].sum()
null_data
# Out:
# name                0
# ingredients         0
# diet                0
# prep_time         0.0
# cook_time         0.0
# flavor_profile      0
# course              0
# state               0
# region              0
# img_url             0
# dtype: object

# %%
food_data['state'].value_counts()
# Out:
# state
# Gujarat            35
# Punjab             33
# Maharashtra        30
# West Bengal        24
# -1                 24
# Assam              21
# Tamil Nadu         20
# Andhra Pradesh     10
# Uttar Pradesh       9
# Odisha              7
# Kerala              7
# Rajasthan           6
# Karnataka           6
# Telangana           5
# Goa                 3
# Bihar               3
# Manipur             2
# Jammu & Kashmir     2
# Madhya Pradesh      2
# NCT of Delhi        1
# Chhattisgarh        1
# Nagaland            1
# Haryana             1
# Tripura             1
# Uttarakhand         1
# Name: count, dtype: int64

# %%
food_data['region'].value_counts()
# Out:
# region
# West          73
# South         58
# North         51
# East          32
# North East    25
# -1            13
# Central        3
# Name: count, dtype: int64

# %%
filtered_df = food_data[food_data['state'] == '-1']
filtered_df
# Out:
#                name                                        ingredients  \
# 29       Brown Rice                   Brown rice, soy sauce, olive oil
# 65             Dosa  Chana dal, urad dal, whole urad dal, blend ric...
# 86             Idli  Split urad dal, urad dal, idli rice, thick poh...
# 96       Kaju katli                     Cashews, ghee, cardamom, sugar
# 111           Kheer                    Milk, rice, sugar, dried fruits
# 113         Khichdi  Moong dal, green peas, ginger, tomato, green c...
# 127   Kulfi falooda  Rose syrup, falooda sev, mixed nuts, saffron, ...
# 134           Laddu                            Gram flour, ghee, sugar
# 137  Lauki ki subji  Bottle gourd, coconut oil, garam masala, ginge...
# 148     Masala Dosa  Chana dal, urad dal, potatoes, idli rice, thic...
# 165       Nankhatai  Refined flour, besan, ghee, powdered sugar, yo...
# 168         Pachadi  Coconut oil, cucumber, curd, curry leaves, mus...
# 175       Pani puri      Kala chana, mashed potato, boondi, sev, lemon
# 179           Papad       Urad dal, sev, lemon juice, chopped tomatoes
# 187         Payasam            Rice, cashew nuts, milk, raisins, sugar
# 207    Rajma chaval  Red kidney beans, garam masala powder, ginger,...
# 210           Rasam  Tomato, curry leaves, garlic, mustard seeds, h...
# 212        Red Rice  Red pepper, red onion, butter, watercress, oli...
# 216          Sambar  Pigeon peas, eggplant, drumsticks, sambar powd...
# 217          Samosa  Potatoes, green peas, garam masala, ginger, dough
# 223           Sevai                     Sevai, parboiled rice, steamer
# 248            Upma   Chana dal, urad dal, ginger, curry leaves, sugar
# 249         Uttapam    Chana dal, urad dal, thick poha, tomato, butter
# 250            Vada  Urad dal, ginger, curry leaves, green chilies,...
#
#            diet  prep_time  cook_time flavor_profile       course state  \
# 29   vegetarian         15         25             -1  main course    -1
# 65   vegetarian        360         90          spicy        snack    -1
# 86   vegetarian        360         90          spicy        snack    -1
# 96   vegetarian         10         20          sweet      dessert    -1
# 111  vegetarian         10         40          sweet      dessert    -1
# 113  vegetarian         40         20          spicy  main course    -1
# 127  vegetarian         45         25          sweet      dessert    -1
# 134  vegetarian         10         40          sweet      dessert    -1
# 137  vegetarian         10         20          spicy  main course    -1
# 148  vegetarian        360         90          spicy        snack    -1
# 165  vegetarian         20         30          sweet      dessert    -1
# 168  vegetarian         10         25             -1  main course    -1
# 175  vegetarian         15          2          spicy        snack    -1
# 179  vegetarian          5          5          spicy        snack    -1
# 187  vegetarian         15         30          sweet      dessert    -1
# 207  vegetarian         15         90          spicy  main course    -1
# 210  vegetarian         10         35          spicy  main course    -1
# 212  vegetarian         -1         -1             -1  main course    -1
# 216  vegetarian         20         45          spicy  main course    -1
# 217  vegetarian         30         30          spicy        snack    -1
# 223  vegetarian        120         30             -1  main course    -1
# 248  vegetarian         10         20          spicy        snack    -1
# 249  vegetarian         10         20          spicy        snack    -1
# 250  vegetarian         15         20          spicy        snack    -1
#
#     region                                            img_url
# 29      -1  https://upload.wikimedia.org/wikipedia/commons...
# 65   South  https://www.archanaskitchen.com/images/archana...
# 86   South  https://www.archanaskitchen.com/images/archana...
# 96      -1  https://crazymasalafood.com/wp-content/images/...
# 111     -1  https://www.crazymasalafood.com/wp-content/ima...
# 113     -1  https://www.vegrecipesofindia.com/wp-content/u...
# 127     -1  https://crazymasalafood.com/wp-content/images/...
# 134     -1  https://crazymasalafood.com/wp-content/images/...
# 137     -1  https://www.vegrecipesofindia.com/wp-content/u...
# 148  South  https://www.archanaskitchen.com/images/archana...
# 165     -1  https://www.crazymasalafood.com/wp-content/ima...
# 168  South  https://www.vegrecipesofindia.com/wp-content/u...
# 175     -1  https://www.archanaskitchen.com/images/archana...
# 179     -1  https://www.archanaskitchen.com/images/archana...
# 187  South  https://www.crazymasalafood.com/wp-content/ima...
# 207  North  https://www.vegrecipesofindia.com/wp-content/u...
# 210  South  https://rakskitchen.net/wp-content/uploads/201...
# 212     -1  https://upload.wikimedia.org/wikipedia/commons...
# 216  South  https://rakskitchen.net/wp-content/uploads/201...
# 217     -1  https://www.archanaskitchen.com/images/archana...
# 223  South  https://rakskitchen.net/wp-content/uploads/201...
# 248     -1  https://www.archanaskitchen.com/images/archana...
# 249  South  https://www.archanaskitchen.com/images/archana...
# 250  South  https://www.archanaskitchen.com/images/archana...

# %%
sns.histplot(data = food_data['prep_time'] , bins = 7 , edgecolor = 'black', color = 'orange')
plt.xlabel('Preparation Time (minutes)')
plt.ylabel('Frequency')
plt.title('Frequency vs Preparation Time')
plt.show()

# %%
food_data['course'].value_counts()
# Out:
# course
# main course    129
# dessert         85
# snack           39
# starter          2
# Name: count, dtype: int64

# %%
food_data['flavor_profile'].value_counts()
# Out:
# flavor_profile
# spicy     133
# sweet      88
# -1         29
# bitter      4
# sour        1
# Name: count, dtype: int64

# %%
food_data['prep_time'].value_counts()
# Out:
# prep_time
#  10     98
#  20     40
# -1      30
#  15     22
#  5      16
#  30     12
#  25      5
#  120     5
#  45      5
#  240     4
#  40      3
#  360     3
#  60      2
#  180     2
#  80      1
#  12      1
#  150     1
#  480     1
#  500     1
#  495     1
#  70      1
#  35      1
# Name: count, dtype: int64

# %%
food_data['cook_time'].value_counts()
# Out:
# cook_time
#  30     59
#  20     42
# -1      28
#  40     27
#  60     22
#  45     15
#  25     13
#  50     10
#  35      9
#  10      7
#  90      7
#  15      5
#  120     3
#  5       3
#  75      1
#  6       1
#  2       1
#  720     1
#  55      1
# Name: count, dtype: int64

# %%
food_data.loc[(food_data['state'] == '-1') & (food_data['name'] == 'Pachadi'), 'state'] = 'Andhra Pradesh'
food_data.loc[(food_data['state'] == '-1') & (food_data['region'] == 'South'), 'state'] = 'Tamil Nadu'
food_data.loc[(food_data['state'] == '-1') & (food_data['region'] == '-1'), ['state', 'region']] = ['Rajasthan', 'North']
food_data.loc[(food_data['state'] == '-1') & (food_data['region'] == 'North') , 'state'] = 'Punjab'
food_data.loc[(food_data['course'] == '-1') | (food_data['flavor_profile'] == '-1'), ['course' , 'flavor_profile']] = ['Not in the list' , 'Not in the list']
food_data.loc[(food_data['prep_time'] == -1.0) | (food_data['cook_time'] == -1.0) ,['prep_time', 'cook_time']] = [int(food_data['prep_time'].median()) , int(food_data['cook_time'].median())]

# %%
sns.boxplot(food_data['prep_time'])
# Out:
# <Axes: ylabel='prep_time'>

# %%
sns.boxplot(food_data['cook_time'])
# Out:
# <Axes: ylabel='cook_time'>

# %%
sns.boxplot(data = food_data , x = 'region' , y = 'prep_time')
plt.title('Region vs Preparation Time')
plt.xlabel('Region')
plt.ylabel('Preparation Time')
plt.show()

# %%
sns.boxplot(data = food_data , x = 'region' , y = 'cook_time' )
plt.title('Region vs Cooking Time')
plt.xlabel('Region')
plt.ylabel('Cooking Time')
plt.show()

# %%
plt.scatter(food_data['prep_time'], food_data['cook_time'], c='g', alpha=0.7, edgecolor='black', label='Prep Time')
plt.scatter(food_data['cook_time'], food_data['prep_time'], c='r', alpha=0.7, edgecolor='black', label='Cook Time')
plt.xlabel('Preparation Time (minutes)')
plt.ylabel('Cooking Time (minutes)')
plt.title('Preparation Time vs Cooking Time')
plt.legend()
plt.show()

# %%
food_data['prep_time'] = mstats.winsorize(food_data['prep_time'], limits = [0.05, 0.12])
food_data['cook_time'] = mstats.winsorize(food_data['cook_time'], limits = [0.05,0.05])

# %%
sns.boxplot(food_data['prep_time'])
# Out:
# <Axes: ylabel='prep_time'>

# %%
sns.boxplot(food_data['cook_time'])
# Out:
# <Axes: ylabel='cook_time'>

# %%
food_data['diet'].value_counts()
# Out:
# diet
# vegetarian        227
# non vegetarian     28
# Name: count, dtype: int64

# %%
sns.histplot(data = food_data['cook_time'] , bins = 7 , edgecolor = 'black', color = 'orange')
plt.xlabel('Preparation Time (minutes)')
plt.ylabel('Frequency')
plt.title('Frequency vs Cooking Time')
plt.show()

# %%
sns.histplot(data = food_data['prep_time'] , bins = 7 , edgecolor = 'black', color = 'orange')
plt.xlabel('Preparation Time (minutes)')
plt.ylabel('Frequency')
plt.title('Frequency vs Preparation Time')
plt.show()

# %%
calculation = food_data['diet'].value_counts()
new_dataframe = calculation.reset_index()
new_dataframe.columns = ['diet' , 'count']
new_dataframe
# Out:
#              diet  count
# 0      vegetarian    227
# 1  non vegetarian     28

# %%
no_of_dishes = food_data.groupby('region')['name'].nunique().reset_index()
no_of_dishes = no_of_dishes.sort_values(by='region', ascending=False)
sns.barplot(data = no_of_dishes , y = 'region' , x = 'name' , color = 'orange' , edgecolor = 'black')
plt.title('No of Dishes in Each Region')
plt.xlabel('No of Dishes')
plt.ylabel("Region")
# Out:
# Text(0, 0.5, 'Region')

# %%
color = {'vegetarian' : 'green' , 'non vegetarian' : 'red'}
sns.barplot(data = new_dataframe, x = "diet" , y = "count" , hue = "diet" , palette = color ,edgecolor = 'black' )
plt.title('Veg vs Non Veg Dishes')
plt.xlabel('Diet')
plt.ylabel('No of Dishes')
plt.show()

# %%
grouped_data = food_data.groupby(['region' , 'diet'])['name'].count().reset_index()
grouped_data = grouped_data.sort_values(by = 'region')
grouped_data['name'] = grouped_data['name'].fillna(0)
pivot_data = grouped_data.pivot(index = 'region', columns = 'diet' , values = 'name')
pivot_data.plot(kind='barh', stacked=True , color = color , edgecolor = 'black')
plt.xlabel('No Of Dishes')
plt.ylabel('Region')
plt.title('Diet Distribution by Region')
plt.show()
pivot_data
# Out:
# diet        non vegetarian  vegetarian
# region
# Central                NaN         3.0
# East                   5.0        27.0
# North                  5.0        59.0
# North East            13.0        12.0
# South                  2.0        56.0
# West                   3.0        70.0

# %%
explode = (0, 0.2)
colors = [ 'skyblue' , 'orange']
data1 = food_data['diet'].value_counts()
plt.pie(data1, labels = data1.index, autopct='%1.1f%%', startangle=200, shadow=True, explode=explode, colors=colors)
plt.title('Diet Distribution')
plt.axis('equal')
plt.show()

# %%
data3 = food_data['region'].value_counts()
pie_data = data3.values
explode1 = [0]*len(data3)
for i in range(len(explode1)):
  explode1[i] = 0.08
plt.pie(pie_data , labels=data3.index, autopct='%1.1f%%', startangle= 70 , shadow = True , explode = explode1 )
plt.title('Region wise Dishes ')
plt.axis('equal')
plt.show()

# %%
state = pd.DataFrame(food_data['state'].value_counts())
state_count = state.reset_index()
state_count.columns = ['state' , 'count']
sns.barplot(data = state_count , x = 'count' , y = 'state', color = 'blue' , edgecolor = 'white')
plt.xlabel('No of Dishes')
plt.ylabel('state')
plt.title('No of Dishes state wise')
plt.gca().set_facecolor("gold")

# %%
region_diet_counts = pd.crosstab(food_data['region'], food_data['cook_time'])
plt.figure(figsize=(12, 5))
sns.heatmap(region_diet_counts, annot= True, cmap='inferno', fmt='d', linewidths=.2)
plt.title('Heatmap of Region vs. Cooking_Time')
plt.xlabel('Cooking_Time')
plt.ylabel('Region')
plt.show()

# %%
region_diet_counts1 = pd.crosstab(food_data['region'], food_data['prep_time'])
plt.figure(figsize=(12, 5))
sns.heatmap(region_diet_counts1, annot= True, cmap='viridis', fmt='d', linewidths=.2)
plt.title('Heatmap of Region vs Preparation_Time')
plt.xlabel('Preparation_Time')
plt.ylabel('Region')
plt.show()

# %%
plt.scatter(food_data['prep_time'], food_data['cook_time'], c='blue', alpha=0.7, edgecolor='black', label='Prep Time')
plt.scatter(food_data['cook_time'], food_data['prep_time'], c='pink', alpha=0.7, edgecolor='black', label='Cook Time')
plt.xlabel('Preparation Time (minutes)')
plt.ylabel('Cooking Time (minutes)')
plt.title('Relationship between Preparation Time and Cooking Time')
plt.legend()
plt.show()

# %%
#hey are you watching
